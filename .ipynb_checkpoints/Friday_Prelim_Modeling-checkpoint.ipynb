# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
"""
Now, I need to check if I have any missing data. I could have missing data for a few of my categories.

"""
# Out:
# '\nNow, I need to check if I have any missing data. I could have missing data for a few of my categories.\n\n'

# %%
dataset = pd.read_csv('Household-V1_2_prelim.csv')

# %%
dataset = dataset.drop(['Unnamed: 0'], axis=1)

# %%
dataset
# Out:
#          SAMPN  RESTY  HHSIZ  HHLIC  INCOM_R  HHVEH_R
# 0      3000056      1      6      4        3        3
# 1      3000128      1      5      3        2        2
# 2      3000139      1      2      2        9        2
# 3      3000146      1      1      1        3        1
# 4      3000157      2      1      0        1        0
# 5      3000239      1      2      2        9        1
# 6      3000250      2      1      1        2        1
# 7      3000275      1      2      2        2        1
# 8      3000296      2      1      0        1        0
# 9      3000403      2      1      1        1        0
# 10     3000407      1      2      2        4        2
# 11     3000448      1      3      3        4        3
# 12     3000451      1      4      1        2        1
# 13     3000486      2      2      2        4        2
# 14     3000490      2      1      0        2        0
# 15     3000498      1      2      2        2        0
# ...

# %%
dataset.RESTY.unique()
# Out:
# array([1, 2, 3, 8, 9])

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.hist(dataset['RESTY'], bins = 9)
plt.title('Residence Type')
plt.xlabel('Type of residence')
plt.ylabel('Quantity')
plt.show()

# %%
dataset.RESTY.value_counts(dropna=False)
# Out:
# 1    11157
# 2     7699
# 3       91
# 8       10
# 9        8
# Name: RESTY, dtype: int64

# %%
dataset.HHSIZ.value_counts(dropna=False)
# Out:
# 2     6709
# 1     5775
# 3     2990
# 4     2453
# 5      763
# 6      197
# 7       49
# 8       21
# 9        6
# 11       1
# 10       1
# Name: HHSIZ, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.hist(dataset['HHSIZ'], bins = 11)
plt.title('Household Size')
plt.xlabel('Number of people in residence')
plt.ylabel('Number of Observations')
plt.show()

# %%
Auto_own_level_freq = dataset.HHVEH_R.value_counts()
print(Auto_own_level_freq)
# Out:
# 2    6242
# 1    5852
# 0    3771
# 3    3100
# Name: HHVEH_R, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.hist(dataset["HHVEH_R"], bins=4)
plt.title("Number of Vehicles owned by household")
plt.xlabel("Number of Vehicles (Range ~ 3 => 3+)")
plt.ylabel("Frequency")
plt.show()

# %%
# 2, 1, 0, 3
labels = ['Two', 'One', 'Zero', 'Three Plus']
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.pie(Auto_own_level_freq, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Number of Vehicles owned by household")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.hist(dataset["INCOM_R"], bins=9)
plt.title("Household Income")
plt.xlabel("Category")
plt.ylabel("Frequency")
plt.show()

# %%
single_family = dataset[dataset["RESTY"] == 1]
multi_family = dataset[dataset["RESTY"] == 2]
multi_family
# Out:
#          SAMPN  RESTY  HHSIZ  HHLIC  INCOM_R  HHVEH_R
# 4      3000157      2      1      0        1        0
# 6      3000250      2      1      1        2        1
# 8      3000296      2      1      0        1        0
# 9      3000403      2      1      1        1        0
# 13     3000486      2      2      2        4        2
# 14     3000490      2      1      0        2        0
# 18     3000598      2      1      0        1        0
# 20     3000616      2      1      1        2        1
# 23     3000686      2      1      0        1        0
# 26     3000711      2      1      0        1        0
# 35     3000815      2      1      1        1        1
# 42     3001059      2      1      0        2        0
# 48     3001190      2      1      1        1        0
# 50     3001293      2      2      2        4        0
# 53     3001346      2      2      2        3        2
# 56     3001559      2      1      1        2        2
# ...

# %%
single_family_veh = single_family.HHVEH_R.value_counts()
single_family_veh
labels = ['Two', 'Three Plus', 'One', 'Zero']
colors = ['gold', 'lightskyblue', 'yellowgreen', 'lightcoral']
explode = (0.1, 0, 0, 0)  # explode 1st slice
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.pie(single_family_veh, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Percentage of Vehicles owned by households with residence type =  Single Family Housing")
plt.show()

# %%
multi_family_veh = multi_family.HHVEH_R.value_counts()
multi_family_veh
# 0, 1, 2, 3
labels = ['Zero', 'One', 'Two', 'Three Plus']
colors = ['lightcoral', 'yellowgreen', 'gold', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.pie(multi_family_veh, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Households who Reside in Multi-Family Housing: Distribution of Vehicle Ownership")
plt.show()

# %%
print(dataset.HHLIC.value_counts())
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.hist(dataset['HHLIC'], bins=8)
plt.title('Frequency of Number of Drivers License Holders in Household')
plt.xlabel('Number of Drivers License Holders')
plt.ylabel('Frequency')
plt.show()
# Out:
# 2    8722
# 1    6472
# 0    1816
# 3    1544
# 4     361
# 5      47
# 7       2
# 6       1
# Name: HHLIC, dtype: int64

# %%
# This needs to be refactored. Just loop through them... DRY!
zero_license_holders = dataset[dataset["HHLIC"] == 0]
one_license_holders = dataset[dataset["HHLIC"] == 1]
two_license_holders = dataset[dataset["HHLIC"] == 2]
three_license_holders = dataset[dataset["HHLIC"] == 3]
four_license_holders = dataset[dataset["HHLIC"] == 4]
five_license_holders = dataset[dataset["HHLIC"] == 5]
six_license_holders = dataset[dataset["HHLIC"] == 6]
seven_license_holders = dataset[dataset["HHLIC"] == 7]

# %%
seven_license_holders
# Out:
#          SAMPN  RESTY  HHSIZ  HHLIC  INCOM_R  HHVEH_R
# 9334   3471304      1      7      7        4        3
# 10993  3527968      1      7      7        3        3

# %%
zero_license_veh = zero_license_holders.HHVEH_R.value_counts()
zero_license_veh
# 0, 1, 2, 3
labels = ['Zero', 'One', 'Two', 'Three Plus']
colors = ['lightcoral', 'yellowgreen', 'gold', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.pie(zero_license_veh, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Households who have zero drivers license: Distribution of Vehicle Ownership")
plt.show()

# %%
one_license_veh = one_license_holders.HHVEH_R.value_counts()
one_license_veh
# 1, 0, 2, 3
labels = ['One', 'Zero','Two', 'Three Plus']
colors = ['yellowgreen', 'lightcoral', 'gold', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.pie(one_license_veh, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Households who have one drivers license: Distribution of Vehicle Ownership")
plt.show()

# %%
two_license_veh = two_license_holders.HHVEH_R.value_counts()
print(two_license_veh)
# 2, 1, 3, 0
labels = ['Two', 'One', 'Three Plus', 'Zero']
colors = ['gold', 'yellowgreen', 'lightskyblue', 'lightcoral']
explode = (0.1, 0, 0, 0)  # explode 1st slice
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.pie(two_license_veh, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Households who have two drivers licenses: Distribution of Vehicle Ownership")
plt.show()
# Out:
# 2    5203
# 1    1645
# 3    1494
# 0     380
# Name: HHVEH_R, dtype: int64

# %%
three_license_veh = three_license_holders.HHVEH_R.value_counts()
print(three_license_veh)
# 3, 2, 1, 0
labels = ['Three Plus', 'Two', 'One', 'Zero']
colors = ['lightskyblue', 'gold', 'yellowgreen', 'lightcoral']
explode = (0.1, 0, 0, 0)  # explode 1st slice
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.pie(three_license_veh, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Households who have three drivers licenses: Distribution of Vehicle Ownership")
plt.show()
# Out:
# 3    1060
# 2     373
# 1      90
# 0      21
# Name: HHVEH_R, dtype: int64
