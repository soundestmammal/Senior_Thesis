# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Household-V1_2_prelim.csv')
dataset.drop(dataset['INCOM_R'], axis=1)
# Out:
#          SAMPN  RESTY  HHSIZ  HHLIC  INCOM_R  HHVEH_R
# 0      3000056      1      6      4        3        3
# 1      3000128      1      5      3        2        2
# 2      3000139      1      2      2        9        2
# 3      3000146      1      1      1        3        1
# 4      3000157      2      1      0        1        0
# 5      3000239      1      2      2        9        1
# 6      3000250      2      1      1        2        1
# 7      3000275      1      2      2        2        1
# 8      3000296      2      1      0        1        0
# 9      3000403      2      1      1        1        0
# 10     3000407      1      2      2        4        2
# 11     3000448      1      3      3        4        3
# 12     3000451      1      4      1        2        1
# 13     3000486      2      2      2        4        2
# 14     3000490      2      1      0        2        0
# 15     3000498      1      2      2        2        0
# ...

# %%
pd.get_dummies(dataset, columns=['RESTY',])
