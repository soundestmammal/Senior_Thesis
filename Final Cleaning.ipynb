# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
dataset = pd.read_excel('./RHTS_MODE_CHOICE/HH_Public.xlsx')
list = ['RECMode', 'RETMode', 'GTYPE', 'STYPE', 'ILANG', 'LTELE', 'HHLNG', 'O_HHLNG', 'DOW', 'HTRIPS', 'HTRIPS_GPS', 'HH_WHT2', 'GEO_GROUP1', 'GEO_GROUP3', 'HTRIPS_V', 'HTRIPS_T', 'HTRIPS_NM', 'HTRIPS_O', 'HTRIPS_WP', 'HTRIPS_NWP', 'HTRIPS_GPS_V', 'HTRIPS_GPS_T', 'HTRIPS_GPS_NM', 'HTRIPS_GPS_O', 'HTRIPS_GPS_WP', 'HTRIPS_GPS_NWP', 'CTFIP',
 'BIN',
 'HHVEH',
 'PARTIAL',
 'HH1',
 'HCITY',
 'HCITY_PL',
 'HCITY_MCD',
 'HSTATE',
 'HZIP',
 'HTAZ',
 'HTRACT',
 'HHSIZ_R',
 'HHSTRUC']
list
# Out:
# ['RECMode',
#  'RETMode',
#  'GTYPE',
#  'STYPE',
#  'ILANG',
#  'LTELE',
#  'HHLNG',
#  'O_HHLNG',
#  'DOW',
#  'HTRIPS',
#  'HTRIPS_GPS',
#  'HH_WHT2',
#  'GEO_GROUP1',
#  'GEO_GROUP3',
#  'HTRIPS_V',
#  'HTRIPS_T',
#  'HTRIPS_NM',
#  'HTRIPS_O',
#  'HTRIPS_WP',
#  'HTRIPS_NWP',
#  'HTRIPS_GPS_V',
#  'HTRIPS_GPS_T',
#  'HTRIPS_GPS_NM',
#  'HTRIPS_GPS_O',
#  'HTRIPS_GPS_WP',
#  'HTRIPS_GPS_NWP',
#  'CTFIP',
#  'BIN',
#  'HHVEH',
#  'PARTIAL',
#  'HH1',
#  'HCITY',
#  'HCITY_PL',
#  'HCITY_MCD',
#  'HSTATE',
#  'HZIP',
#  'HTAZ',
#  'HTRACT',
#  'HHSIZ_R',
#  'HHSTRUC']

# %%
clean_data = dataset.drop(list, axis=1)
clean_data
# Out:
#          SAMPN  RESTY  HHSIZ  INCOM  HHSTU  HHWRK  HHLIC  HHCHD  GEO_GROUP2  \
# 0      3000056      1      6      5      4      4      4      2           4
# 1      3000128      1      5      4      3      3      3      2           3
# 2      3000139      1      2     99      0      0      2      0           5
# 3      3000146      1      1      5      0      1      1      0           5
# 4      3000157      2      1      1      0      0      0      0           5
# 5      3000239      1      2     99      0      0      2      0           3
# 6      3000250      2      1      3      0      0      1      0           2
# 7      3000275      1      2      4      0      0      2      0           2
# 8      3000296      2      1      1      0      0      0      0           1
# 9      3000403      2      1      2      0      0      1      0           1
# 10     3000407      1      2      6      0      2      2      0           6
# ...

# %%
clean_data.to_csv('Household-V3.csv', sep=',')

# %%
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
dataset3 = pd.read_csv('Household-V3.csv')
dataset3
# Out:
#        Unnamed: 0    SAMPN  RESTY  HHSIZ  INCOM  HHSTU  HHWRK  HHLIC  HHCHD  \
# 0               0  3000056      1      6      5      4      4      4      2
# 1               1  3000128      1      5      4      3      3      3      2
# 2               2  3000139      1      2     99      0      0      2      0
# 3               3  3000146      1      1      5      0      1      1      0
# 4               4  3000157      2      1      1      0      0      0      0
# 5               5  3000239      1      2     99      0      0      2      0
# 6               6  3000250      2      1      3      0      0      1      0
# 7               7  3000275      1      2      4      0      0      2      0
# 8               8  3000296      2      1      1      0      0      0      0
# 9               9  3000403      2      1      2      0      0      1      0
# 10             10  3000407      1      2      6      0      2      2      0
# ...

# %%
dataset3 = dataset3
dataset3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-f88a328ef81c> in <module>()
# ----> 1 dataset3 = dataset3.drop(['Unnamed: 0'], axis=1)
#       2 dataset3
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
# ...
